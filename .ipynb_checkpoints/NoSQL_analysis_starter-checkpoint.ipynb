# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
print(mongo.list_database_names())
db = mongo['uk_foods']
# Out:
# ['admin', 'config', 'fruit', 'local', 'met', 'uk_foods']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments=db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query ={'scores.Hygiene':20}
results={'scores.Hygiene':20}
# Use count_documents to display the number of documents in the result
print( f" There are {establishments.count_documents(query)} establishments with a hygiene score of 20")
# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
#  There are 41 establishments with a hygiene score of 20
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641624f6169c9cb1dd69c48c'),
#  'convertedlatitude': None,
#  'convertedlongitude': None,
# ...

# %%
#convert query into list
result=list(establishments.find(query))

# %%
# Convert the result to a Pandas DataFrame
hygiene_df=pd.DataFrame(result)
# Display the number of rows in the DataFrame
len(hygiene_df. index)
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  641624f6169c9cb1dd69c48c   110681                  0
# 1  641624f6169c9cb1dd69c80c   612039                  0
# 2  641624f7169c9cb1dd69cb17   730933                  0
# 3  641624f7169c9cb1dd69cd05   172735                  0
# 4  641624f7169c9cb1dd69cd15   172953                  0
# 5  641624f7169c9cb1dd69d6be   512854                  0
# 6  641624f7169c9cb1dd69d8d2  1537089                  0
# 7  641624f7169c9cb1dd69edfd   155648                  0
# 8  641624f7169c9cb1dd69f242  1012883                  0
# 9  641624f7169c9cb1dd69fa55   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={"LocalAuthorityName": {"$regex":"London"},
        "RatingValue":{'$gte':'4'}}

# Use count_documents to display the number of documents in the resulte
print(f" There are {establishments.count_documents(query)} establishments with ratings of 4 or above")
# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
#  There are 34 establishments with ratings of 4 or above
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641624f7169c9cb1dd69dea6'),
#  'convertedlatitude': None,
# ...

# %%
#convert query into list
result2=list(establishments.find(query))

# %%
# Convert the result to a Pandas DataFrame
rating_df=pd.DataFrame(result2)
# Display the number of rows in the DataFrame
len(rating_df. index)
# Out:
# 34

# %%
# Display the first 10 rows of the DataFrame
rating_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  641624f7169c9cb1dd69dea6   621707                  0
# 1  641624f7169c9cb1dd69e1e0  1130836                  0
# 2  641624f7169c9cb1dd69ed1a   293783                  0
# 3  641624f7169c9cb1dd69fb19   294474                  0
# 4  641624f7169c9cb1dd69fb1a  1315095                  0
# 5  641624f7169c9cb1dd6a0224   294900                  0
# 6  641624f8169c9cb1dd6a232e  1252616                  0
# 7  641624f8169c9cb1dd6a2331   293756                  0
# 8  641624f8169c9cb1dd6a26f8   878523                  0
# 9  641624f8169c9cb1dd6a2712   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Find the latitude and longitude of "Penang Flavours"
pprint(establishments.find_one({'BusinessName': 'Penang Flavours'}, {'geocode.latitude', 'geocode.longitude'}))
# Out:
# {'_id': ObjectId('64162fd09a5392ebe54bfd52'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'}}

# %%
# Convert the latitude and longitude from string to float
latitude = float(location['geocode']['latitude'])
longitude = float(location['geocode']['longitude'])

# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01

max_lat = latitude + degree_search
min_lat = latitude - degree_search
max_lon = longitude + degree_search
min_lon = longitude - degree_search

query = {"RatingValue": "5", "geocode.latitude": {"$gte": min_lat, "$lte": max_lat}, 'geocode.longitude': {'$gte': min_lon, '$lte': max_lon}}

sort = ['scores.Hygiene', 1]


# Print the results
#result= list(establishments.find(query).sort(sort).limit(5))
result = list(establishments.find(query.sort(sort).limit(5)))
#print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5968\1824226686.py in <module>
#      21 # Print the results
#      22 #result= list(establishments.find(query).sort(sort).limit(5))
# ---> 23 result = list(establishments.find(query.sort(sort).limit(5)))
#      24 #print(result)
#
# AttributeError: 'dict' object has no attribute 'sort'

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
